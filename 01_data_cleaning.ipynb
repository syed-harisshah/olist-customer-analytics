# %%
import pandas as pd
import duckdb
import sklearn
import lifetimes

print("pandas:", pd.__version__)
print("duckdb:", duckdb.__version__)
print("sklearn:", sklearn.__version__)
print("lifetimes:", lifetimes.__version__)
# Out:
# pandas: 3.0.3
# duckdb: 1.5.3
# sklearn: 1.8.0
# lifetimes: 0.11.3
